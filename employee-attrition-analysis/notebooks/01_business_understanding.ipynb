# %% [markdown]
# ### Understand the Dataset

# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
# Loading the data 
df = pd.read_csv(r"D:\NTI-ML\nti-projects\employee-attrition-analysis\data\raw\employee_attrition_course.csv")
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate                Department  \
# 0  41.0       Yes      Travel_Rarely       1102                     sales
# 1  49.0        No  Travel_Frequently        279  Research and Development
# 2  37.0       Yes      Travel_Rarely       1373  Research and Development
# 3  33.0        No  Travel_Frequently       1392  Research and Development
# 4  27.0        No      Travel_Rarely        591  Research and Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# Show the shape 
print("(Rows , Columns)",df.shape)
# Out:
# (Rows , Columns) (1495, 37)

# %%
# Overviow
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495 entries, 0 to 1494
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1451 non-null   float64
#  1   Attrition                 1495 non-null   object
#  2   BusinessTravel            1495 non-null   object
#  3   DailyRate                 1495 non-null   int64
#  4   Department                1495 non-null   object
#  5   DistanceFromHome          1495 non-null   int64
#  6   Education                 1495 non-null   int64
#  7   EducationField            1466 non-null   object
#  8   EmployeeCount             1495 non-null   int64
#  9   EmployeeNumber            1495 non-null   int64
#  10  EnvironmentSatisfaction   1495 non-null   int64
#  11  Gender                    1495 non-null   object
#  12  HourlyRate                1495 non-null   int64
#  13  JobInvolvement            1495 non-null   int64
# ...

# %%
# Statistical description of numerical columns
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1451.000000  1495.000000       1495.000000  1495.000000         1495.0
# mean     36.973122   800.762542          9.442140     2.915050            1.0
# std       9.229636   403.789611          9.590084     1.026494            0.0
# min      16.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   798.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      78.000000  1499.000000        150.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1495.000000              1495.000000  1495.000000     1495.000000
# mean      1027.762542                 2.730435    65.882943        2.728428
# ...

# %%
# Statistical description of categorical columns
df.describe(include='object')
# Out:
#        Attrition BusinessTravel                Department EducationField  \
# count       1495           1495                      1495           1466
# unique         2              7                         3              6
# top           No  Travel_Rarely  Research and Development  Life Sciences
# freq        1256           1051                       973            605
#
#        Gender          JobRole MaritalStatus Over18 OverTime ManagerNotes
# count    1495             1480          1495   1495     1495          598
# unique      4               12             3      1        2            3
# top      Male  Sales Executive       Married      Y       No         Good
# freq      878              321           690   1495     1070          211

# %% [markdown]
# Business Meaning: Quick Notes on Key Columns
#
# - **Attrition:** Target Variable (Yes = Left / No = Still Employed).
#
# - **Overtime, Monthly Income, Job Satisfaction, Department:** Key candidates influencing the decision.
#
# - **Employee Count, Standard Hours, Over 18:** Columns that appear to have fixed values ​​(we will verify these in the quality assessment).
#
# - **RecordID / EmployeeNumber:** ID columns, not analytical
